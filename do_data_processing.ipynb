# %%
import os
import numpy
import pandas as pd
pd.options.display.float_format = '{:.8f}'.format
import mne

# %%
raw_path = '/workspace/Competition/PSG/01_DATA/raw'

# %%
raw_files = os.listdir(raw_path)
raw_files = [x for x in raw_files if not x.startswith('.')]

# %%
raw_files
# Out:
# ['1_4789.edf',
#  '1_4789.tsv',
#  '10_22339.edf',
#  '10_22339.tsv',
#  '16_24241.edf',
#  '16_24241.tsv',
#  '22_23233.edf',
#  '22_23233.tsv',
#  '25_10579.edf',
#  '25_10579.tsv',
#  '25_18085.edf',
#  '25_18085.tsv',
#  '28_15280.edf',
#  '28_15280.tsv',
#  '31_4429.edf',
#  '31_4429.tsv',
#  '37_14779.edf',
#  '37_14779.tsv',
#  '7_12595.edf',
#  '7_12595.tsv',
#  '40_14503.edf',
#  '40_14503.tsv',
#  '43_175.edf',
#  '43_175.tsv',
#  '46_11305.edf',
#  '46_11305.tsv',
#  '55_6112.edf',
#  '55_6112.tsv',
#  '61_19477.edf',
#  '61_19477.tsv',
#  '64_14908.edf',
#  '64_14908.tsv',
#  '64_25396.edf',
#  '64_25396.tsv',
#  '67_5998.edf',
#  '67_5998.tsv',
#  '70_20743.edf',
#  '70_20743.tsv',
#  '82_20809.edf',
#  '82_20809.tsv',
#  '100_23083.edf',
#  '100_23083.tsv',
#  '103_12325.edf',
#  '103_12325.tsv',
#  '115_22774.edf',
#  '115_22774.tsv',
#  '121_23845.edf',
#  '121_23845.tsv',
#  '127_19126.edf',
#  '127_19126.tsv',
#  '130_5164.edf',
#  '130_5164.tsv',
#  '136_4501.edf',
#  '136_4501.tsv',
#  '91_15028.edf',
#  '91_15028.tsv',
#  '91_18331.edf',
#  '91_18331.tsv',
#  '91_3787.edf',
#  '91_3787.tsv',
#  '139_20275.edf',
#  '139_20275.tsv',
#  '145_1537.edf',
#  '145_1537.tsv',
#  '148_568.edf',
#  '148_568.tsv',
#  '151_23734.edf',
#  '151_23734.tsv',
#  '154_18469.edf',
#  '154_18469.tsv',
#  '157_6391.edf',
#  '157_6391.tsv',
#  '160_11500.edf',
#  '160_11500.tsv',
#  '160_12856.edf',
#  '160_12856.tsv',
#  '160_2740.edf',
#  '160_2740.tsv',
#  '163_20485.edf',
#  '163_20485.tsv',
#  '166_10357.edf',
#  '166_10357.tsv',
#  '181_12274.edf',
#  '181_12274.tsv',
#  '184_2509.edf',
#  '184_2509.tsv',
#  '187_6160.edf',
#  '187_6160.tsv',
#  '190_9877.edf',
#  '190_9877.tsv',
#  '202_13666.edf',
#  '202_13666.tsv',
#  '205_23176.edf',
#  '205_23176.tsv',
#  '211_25741.edf',
#  '211_25741.tsv',
#  '211_8290.edf',
#  '211_8290.tsv',
#  '220_7708.edf',
#  '220_7708.tsv']

# %%
edf_files = [x for x in raw_files if 'edf' in x]
tsv_files = [x for x in raw_files if 'tsv' in x]
ids = [x.split('.')[0] for x in raw_files]

# %%
tsv_files
# Out:
# ['1_4789.tsv',
#  '10_22339.tsv',
#  '16_24241.tsv',
#  '22_23233.tsv',
#  '25_10579.tsv',
#  '25_18085.tsv',
#  '28_15280.tsv',
#  '31_4429.tsv',
#  '37_14779.tsv',
#  '7_12595.tsv',
#  '40_14503.tsv',
#  '43_175.tsv',
#  '46_11305.tsv',
#  '55_6112.tsv',
#  '61_19477.tsv',
#  '64_14908.tsv',
#  '64_25396.tsv',
#  '67_5998.tsv',
#  '70_20743.tsv',
#  '82_20809.tsv',
#  '100_23083.tsv',
#  '103_12325.tsv',
#  '115_22774.tsv',
#  '121_23845.tsv',
#  '127_19126.tsv',
#  '130_5164.tsv',
#  '136_4501.tsv',
#  '91_15028.tsv',
#  '91_18331.tsv',
#  '91_3787.tsv',
#  '139_20275.tsv',
#  '145_1537.tsv',
#  '148_568.tsv',
#  '151_23734.tsv',
#  '154_18469.tsv',
#  '157_6391.tsv',
#  '160_11500.tsv',
#  '160_12856.tsv',
#  '160_2740.tsv',
#  '163_20485.tsv',
#  '166_10357.tsv',
#  '181_12274.tsv',
#  '184_2509.tsv',
#  '187_6160.tsv',
#  '190_9877.tsv',
#  '202_13666.tsv',
#  '205_23176.tsv',
#  '211_25741.tsv',
#  '211_8290.tsv',
#  '220_7708.tsv']

# %%
rawedf = mne.io.read_raw_edf(edfpath)
# Out:
# Extracting EDF parameters from /workspace/Competition/PSG/01_DATA/raw/220_7708.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...

# %%
edf_files
# Out:
# ['1_4789.edf',
#  '10_22339.edf',
#  '16_24241.edf',
#  '22_23233.edf',
#  '25_10579.edf',
#  '25_18085.edf',
#  '28_15280.edf',
#  '31_4429.edf',
#  '37_14779.edf',
#  '7_12595.edf',
#  '40_14503.edf',
#  '43_175.edf',
#  '46_11305.edf',
#  '55_6112.edf',
#  '61_19477.edf',
#  '64_14908.edf',
#  '64_25396.edf',
#  '67_5998.edf',
#  '70_20743.edf',
#  '82_20809.edf',
#  '100_23083.edf',
#  '103_12325.edf',
#  '115_22774.edf',
#  '121_23845.edf',
#  '127_19126.edf',
#  '130_5164.edf',
#  '136_4501.edf',
#  '91_15028.edf',
#  '91_18331.edf',
#  '91_3787.edf',
#  '139_20275.edf',
#  '145_1537.edf',
#  '148_568.edf',
#  '151_23734.edf',
#  '154_18469.edf',
#  '157_6391.edf',
#  '160_11500.edf',
#  '160_12856.edf',
#  '160_2740.edf',
#  '163_20485.edf',
#  '166_10357.edf',
#  '181_12274.edf',
#  '184_2509.edf',
#  '187_6160.edf',
#  '190_9877.edf',
#  '202_13666.edf',
#  '205_23176.edf',
#  '211_25741.edf',
#  '211_8290.edf',
#  '220_7708.edf']

# %%
tsvpath = '/workspace/Competition/PSG/01_DATA/raw'

# %%
file_1 = pd.read_csv( tsvpath +'/1_4789.tsv',delimiter = '\t')

# %%
file_stage = file_1[(file_1['description']=='Sleep stage W')|(file_1['description']=='Sleep stage N1')|(file_1['description']=='Sleep stage N2')|
(file_1['description']=='Sleep stage N3')|
(file_1['description']=='Sleep stage R')|
(file_1['description']=='Sleep stage ?')]

file_stage
# Out:
#               onset    duration    description
# 29    5940.26171875 30.00000000  Sleep stage W
# 36    5970.26171875 30.00000000  Sleep stage W
# 37    6000.26171875 30.00000000  Sleep stage W
# 38    6030.26171875 30.00000000  Sleep stage W
# 39    6060.26171875 30.00000000  Sleep stage W
# ...             ...         ...            ...
# 1130 34530.26171875 30.00000000  Sleep stage ?
# 1131 34560.26171875 30.00000000  Sleep stage ?
# 1132 34590.26171875 30.00000000  Sleep stage ?
# 1133 34620.26171875 30.00000000  Sleep stage ?
# 1134 34650.26171875 25.73828125  Sleep stage ?
#
# [958 rows x 3 columns]

# %%
file_stage=file_stage.reset_index()

# %%
file_stage=file_stage.drop('index', axis = 1 )
file_stage
# Out:
#              onset    duration    description
# 0    5940.26171875 30.00000000  Sleep stage W
# 1    5970.26171875 30.00000000  Sleep stage W
# 2    6000.26171875 30.00000000  Sleep stage W
# 3    6030.26171875 30.00000000  Sleep stage W
# 4    6060.26171875 30.00000000  Sleep stage W
# ..             ...         ...            ...
# 953 34530.26171875 30.00000000  Sleep stage ?
# 954 34560.26171875 30.00000000  Sleep stage ?
# 955 34590.26171875 30.00000000  Sleep stage ?
# 956 34620.26171875 30.00000000  Sleep stage ?
# 957 34650.26171875 25.73828125  Sleep stage ?
#
# [958 rows x 3 columns]

# %%
file_stage2 = pd.DataFrame(file_stage)

for i in range(len(file_stage['description'])):
    if file_stage['description'][i]!=file_stage['description'][i+1]:
        # file_stage3 = file_stage3.merge(file_stage.iloc[i:i+1,:], on='left') 
        file_stage2['description'][i+1] = file_stage['description'][i+1]
        print('Stage is created')
    else :
        file_stage2=file_stage2.drop([i+1], axis = 0)
        print('Stage is same')
# Out:
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is created
# Stage is same
# Stage is same
# Stage is created
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is created
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is created
# Stage is created
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is created
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is created
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is created
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is created
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is created
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is created
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is created
# Stage is created
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is created
# Stage is same
# Stage is created
# Stage is same
# Stage is same
# Stage is same
# Stage is created
# Stage is created
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is created
# Stage is created
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is created
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is created
# Stage is same
# Stage is same
# Stage is same
# Stage is created
# Stage is created
# Stage is created
# Stage is created
# Stage is created
# Stage is created
# Stage is same
# Stage is created
# Stage is same
# Stage is same
# Stage is created
# Stage is created
# Stage is same
# Stage is created
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is created
# Stage is created
# Stage is same
# Stage is same
# Stage is created
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is created
# Stage is same
# Stage is created
# Stage is same
# Stage is created
# Stage is same
# Stage is created
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is created
# Stage is created
# Stage is same
# /tmp/ipykernel_24390/300368075.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   file_stage2['description'][i+1] = file_stage['description'][i+1]
# /tmp/ipykernel_24390/300368075.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   file_stage2['description'][i+1] = file_stage['description'][i+1]
# /tmp/ipykernel_24390/300368075.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   file_stage2['description'][i+1] = file_stage['description'][i+1]
# /tmp/ipykernel_24390/300368075.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   file_stage2['description'][i+1] = file_stage['description'][i+1]
# /tmp/ipykernel_24390/300368075.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   file_stage2['description'][i+1] = file_stage['description'][i+1]
# /tmp/ipykernel_24390/300368075.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   file_stage2['description'][i+1] = file_stage['description'][i+1]
# /tmp/ipykernel_24390/300368075.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   file_stage2['description'][i+1] = file_stage['description'][i+1]
# /tmp/ipykernel_24390/300368075.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   file_stage2['description'][i+1] = file_stage['description'][i+1]
# /tmp/ipykernel_24390/300368075.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   file_stage2['description'][i+1] = file_stage['description'][i+1]
# /tmp/ipykernel_24390/300368075.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   file_stage2['description'][i+1] = file_stage['description'][i+1]
# /tmp/ipykernel_24390/300368075.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   file_stage2['description'][i+1] = file_stage['description'][i+1]
# /tmp/ipykernel_24390/300368075.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   file_stage2['description'][i+1] = file_stage['description'][i+1]
# /tmp/ipykernel_24390/300368075.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   file_stage2['description'][i+1] = file_stage['description'][i+1]
# /tmp/ipykernel_24390/300368075.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   file_stage2['description'][i+1] = file_stage['description'][i+1]
# /tmp/ipykernel_24390/300368075.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   file_stage2['description'][i+1] = file_stage['description'][i+1]
# /tmp/ipykernel_24390/300368075.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   file_stage2['description'][i+1] = file_stage['description'][i+1]
# /tmp/ipykernel_24390/300368075.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   file_stage2['description'][i+1] = file_stage['description'][i+1]
# /tmp/ipykernel_24390/300368075.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   file_stage2['description'][i+1] = file_stage['description'][i+1]
# /tmp/ipykernel_24390/300368075.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   file_stage2['description'][i+1] = file_stage['description'][i+1]
# /tmp/ipykernel_24390/300368075.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   file_stage2['description'][i+1] = file_stage['description'][i+1]
# /tmp/ipykernel_24390/300368075.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   file_stage2['description'][i+1] = file_stage['description'][i+1]
# /tmp/ipykernel_24390/300368075.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   file_stage2['description'][i+1] = file_stage['description'][i+1]
# /tmp/ipykernel_24390/300368075.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   file_stage2['description'][i+1] = file_stage['description'][i+1]
# /tmp/ipykernel_24390/300368075.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   file_stage2['description'][i+1] = file_stage['description'][i+1]
# /tmp/ipykernel_24390/300368075.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   file_stage2['description'][i+1] = file_stage['description'][i+1]
# /tmp/ipykernel_24390/300368075.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   file_stage2['description'][i+1] = file_stage['description'][i+1]
# /tmp/ipykernel_24390/300368075.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   file_stage2['description'][i+1] = file_stage['description'][i+1]
# /tmp/ipykernel_24390/300368075.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   file_stage2['description'][i+1] = file_stage['description'][i+1]
# /tmp/ipykernel_24390/300368075.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   file_stage2['description'][i+1] = file_stage['description'][i+1]
# /tmp/ipykernel_24390/300368075.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   file_stage2['description'][i+1] = file_stage['description'][i+1]
# /tmp/ipykernel_24390/300368075.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   file_stage2['description'][i+1] = file_stage['description'][i+1]
# /tmp/ipykernel_24390/300368075.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   file_stage2['description'][i+1] = file_stage['description'][i+1]
# /tmp/ipykernel_24390/300368075.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   file_stage2['description'][i+1] = file_stage['description'][i+1]
# Stage is same
# Stage is same
# Stage is created
# Stage is created
# Stage is created
# Stage is created
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is created
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is created
# Stage is same
# Stage is created
# Stage is created
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is created
# Stage is created
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is created
# Stage is same
# Stage is created
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is created
# Stage is same
# Stage is same
# Stage is created
# Stage is created
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is created
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is created
# Stage is created
# Stage is same
# Stage is created
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is created
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is created
# Stage is created
# Stage is created
# Stage is created
# Stage is same
# Stage is created
# Stage is same
# Stage is same
# Stage is created
# Stage is created
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is created
# Stage is created
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# Stage is same
# /tmp/ipykernel_24390/300368075.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   file_stage2['description'][i+1] = file_stage['description'][i+1]
# /tmp/ipykernel_24390/300368075.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   file_stage2['description'][i+1] = file_stage['description'][i+1]
# /tmp/ipykernel_24390/300368075.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   file_stage2['description'][i+1] = file_stage['description'][i+1]
# /tmp/ipykernel_24390/300368075.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   file_stage2['description'][i+1] = file_stage['description'][i+1]
# /tmp/ipykernel_24390/300368075.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   file_stage2['description'][i+1] = file_stage['description'][i+1]
# /tmp/ipykernel_24390/300368075.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   file_stage2['description'][i+1] = file_stage['description'][i+1]
# /tmp/ipykernel_24390/300368075.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   file_stage2['description'][i+1] = file_stage['description'][i+1]
# /tmp/ipykernel_24390/300368075.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   file_stage2['description'][i+1] = file_stage['description'][i+1]
# /tmp/ipykernel_24390/300368075.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   file_stage2['description'][i+1] = file_stage['description'][i+1]
# /tmp/ipykernel_24390/300368075.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   file_stage2['description'][i+1] = file_stage['description'][i+1]
# /tmp/ipykernel_24390/300368075.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   file_stage2['description'][i+1] = file_stage['description'][i+1]
# /tmp/ipykernel_24390/300368075.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   file_stage2['description'][i+1] = file_stage['description'][i+1]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File /usr/local/lib/python3.9/dist-packages/pandas/core/indexes/range.py:385, in RangeIndex.get_loc(self, key, method, tolerance)
#     384 try:
# --> 385     return self._range.index(new_key)
#     386 except ValueError as err:
#
# ValueError: 958 is not in range
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Input In [227], in <cell line: 3>()
#       1 file_stage2 = pd.DataFrame(file_stage)
#       3 for i in range(len(file_stage['description'])):
# ----> 4     if file_stage['description'][i]!=file_stage['description'][i+1]:
#       5         # file_stage3 = file_stage3.merge(file_stage.iloc[i:i+1,:], on='left')
#       6         file_stage2['description'][i+1] = file_stage['description'][i+1]
#       7         print('Stage is created')
#
# File /usr/local/lib/python3.9/dist-packages/pandas/core/series.py:958, in Series.__getitem__(self, key)
#     955     return self._values[key]
#     957 elif key_is_scalar:
# --> 958     return self._get_value(key)
#     960 if is_hashable(key):
#     961     # Otherwise index.get_value will raise InvalidIndexError
#     962     try:
#     963         # For labels that don't resolve as scalars like tuples and frozensets
#
# File /usr/local/lib/python3.9/dist-packages/pandas/core/series.py:1069, in Series._get_value(self, label, takeable)
#    1066     return self._values[label]
#    1068 # Similar to Index.get_value, but we do not fall back to positional
# -> 1069 loc = self.index.get_loc(label)
#    1070 return self.index._get_values_for_loc(self, loc, label)
#
# File /usr/local/lib/python3.9/dist-packages/pandas/core/indexes/range.py:387, in RangeIndex.get_loc(self, key, method, tolerance)
#     385         return self._range.index(new_key)
#     386     except ValueError as err:
# --> 387         raise KeyError(key) from err
#     388 self._check_indexing_error(key)
#     389 raise KeyError(key)
#
# KeyError: 958

# %%
file_stage2.info()

# %%
file_stage2 = file_stage2.drop('duration', axis = 1)
file_stage2
# Out:
#              onset     description
# 0    5940.26171875   Sleep stage W
# 12   6300.26171875  Sleep stage N1
# 15   6390.26171875  Sleep stage N2
# 29   6810.26171875  Sleep stage N3
# 113  9330.26171875  Sleep stage N2
# ..             ...             ...
# 834 30960.26171875  Sleep stage N1
# 837 31050.26171875   Sleep stage ?
# 838 31080.26171875  Sleep stage N2
# 854 31560.26171875   Sleep stage W
# 855 31590.26171875   Sleep stage ?
#
# [70 rows x 2 columns]

# %%
file_stage2 = file_stage2.reset_index()
file_stage2 = file_stage2.drop('index',axis=1)
file_stage2
# Out:
#             onset     description
# 0   5940.26171875   Sleep stage W
# 1   6300.26171875  Sleep stage N1
# 2   6390.26171875  Sleep stage N2
# 3   6810.26171875  Sleep stage N3
# 4   9330.26171875  Sleep stage N2
# ..            ...             ...
# 65 30960.26171875  Sleep stage N1
# 66 31050.26171875   Sleep stage ?
# 67 31080.26171875  Sleep stage N2
# 68 31560.26171875   Sleep stage W
# 69 31590.26171875   Sleep stage ?
#
# [70 rows x 2 columns]

# %%
file_que = file_stage2[(file_stage2['description']=='Sleep stage ?')]
file_que
# Out:
#             onset    description
# 66 31050.26171875  Sleep stage ?
# 69 31590.26171875  Sleep stage ?

# %%
file_stage2['onset'][1]
# Out:
# 6300.26171875

# %%
file_1 = numpy.load('/workspace/Competition/PSG/01_DATA/eeg_7_channel/npy/1_4789.npy')

# %%
ex = {file_stage2['description'][0]:file_1[0][int(256*file_stage2['onset'][0]):int(256*file_stage2['onset'][0+1])]}
ex1 = {file_stage2['description'][1]:file_1[0][int(256*file_stage2['onset'][1]):int(256*file_stage2['onset'][1+1])]}
ex.update(ex1)
ex
# Out:
# {'Sleep stage W': array([-3.97650111e-05, -2.74967575e-05, -1.18104829e-05, ...,
#         -5.27962158e-06,  8.39246204e-06, -5.18806744e-07]),
#  'Sleep stage N1': array([-3.14030671e-05, -1.74258030e-05,  1.66323339e-05, ...,
#          8.65796902e-05,  7.40062562e-05,  4.19012741e-05])}

# %%
file_stage2
# Out:
#             onset     description
# 0   5940.26171875   Sleep stage W
# 1   6300.26171875  Sleep stage N1
# 2   6390.26171875  Sleep stage N2
# 3   6810.26171875  Sleep stage N3
# 4   9330.26171875  Sleep stage N2
# ..            ...             ...
# 65 30960.26171875  Sleep stage N1
# 66 31050.26171875   Sleep stage ?
# 67 31080.26171875  Sleep stage N2
# 68 31560.26171875   Sleep stage W
# 69 31590.26171875   Sleep stage ?
#
# [70 rows x 2 columns]

# %%
len(file_1[0][int(256*file_stage2['onset'][0]):int(256*file_stage2['onset'][0+1])])
# Out:
# 92160

# %%
import numpy as np

ex = {file_stage2['description'][0]:file_1[0][int(256*file_stage2['onset'][0]):int(256*file_stage2['onset'][0+1])]}
for j in range(1,len(file_stage2['onset'])-1):
    
    ex1 = {file_stage2['description'][j]+','+str(j):file_1[0][int(256*file_stage2['onset'] [j]):int(256*file_stage2['onset'][j+1])]} 
    ex.update(ex1)
ex
# Out:
# {'Sleep stage W': array([-3.97650111e-05, -2.74967575e-05, -1.18104829e-05, ...,
#         -5.27962158e-06,  8.39246204e-06, -5.18806744e-07]),
#  'Sleep stage N1,1': array([-3.14030671e-05, -1.74258030e-05,  1.66323339e-05, ...,
#          8.65796902e-05,  7.40062562e-05,  4.19012741e-05]),
#  'Sleep stage N2,2': array([ 5.69161517e-05,  5.72213321e-05,  6.43625544e-05, ...,
#         -3.05180438e-08, -3.21965362e-05, -5.79842832e-07]),
#  'Sleep stage N3,3': array([ 4.73029679e-06,  2.87174792e-05, -1.52590219e-07, ...,
#         -4.02532998e-05, -6.25314717e-05, -5.00801099e-05]),
#  'Sleep stage N2,4': array([-4.46478981e-05, -2.99992370e-05, -7.73632410e-05, ...,
#          5.09651331e-06,  3.04875257e-05,  5.46272984e-06]),
#  'Sleep stage N3,5': array([-2.68253605e-05, -1.36415656e-05,  3.61638819e-05, ...,
#          4.55024033e-05,  8.63660639e-06,  1.29091325e-05]),
#  'Sleep stage N2,6': array([ 2.47501335e-05,  3.41496910e-05,  2.45670253e-05, ...,
#          8.45349813e-06, -2.95109483e-05, -1.48012512e-05]),
#  'Sleep stage N3,7': array([-2.41092546e-06,  9.79629206e-06, -2.02944991e-05, ...,
#         -4.51972229e-05, -8.21850919e-05, -5.82589456e-05]),
#  'Sleep stage N1,65': array([-6.22262913e-05, -6.30197604e-05, -9.34767681e-05, ...,
#         -3.05180438e-08, -3.05180438e-08, -3.05180438e-08]),
#  'Sleep stage ?,66': array([-3.05180438e-08, -3.05180438e-08, -3.05180438e-08, ...,
#         -3.05180438e-08, -3.05180438e-08, -3.05180438e-08]),
#  'Sleep stage N2,67': array([-3.05180438e-08, -3.05180438e-08, -3.05180438e-08, ...,
#          1.13832303e-05,  8.45349813e-06,  1.15663386e-05]),
#  'Sleep stage W,68': array([ 2.04776074e-05,  1.33974212e-05, -7.84313725e-06, ...,
#         -9.48195621e-05, -9.40871290e-05, -7.18699931e-05])}

# %%
ex_frame = pd.DataFrame()
ex_frame[['Stage','Onset']]=''
ex_frame.loc[0]= [file_stage2['description'][0],0]

for i in range(1,len(file_stage2['onset'])):
        ex_frame.loc[i]= [file_stage2['description'][i],len(file_1[0][int(256*file_stage2['onset'][i-1]):int(256*file_stage2['onset'][i])])+ex_frame['Onset'][i-1]]
for i in range(1,len(file_stage2['onset'])):
    if ex_frame['Stage'][i-1]=='Sleep stage ?':
        ex_frame['Onset'][i]=0
        
    else: 
        ex_frame.loc[i]= [file_stage2['description'][i],len(file_1[0][int(256*file_stage2['onset'][i-1]):int(256*file_stage2['onset'][i])])+ex_frame['Onset'][i-1]]
spac = ex_frame[ex_frame['Stage']=='Sleep stage ?'].index
ex_frame = ex_frame.drop(spac, inplace=False)
ex_frame
# Out:
# /tmp/ipykernel_24390/804659913.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ex_frame['Onset'][i]=0
#              Stage    Onset
# 0    Sleep stage W        0
# 1   Sleep stage N1    92160
# 2   Sleep stage N2   115200
# 3   Sleep stage N3   222720
# 4   Sleep stage N2   867840
# ..             ...      ...
# 63  Sleep stage N1  6382080
# 64  Sleep stage N2  6389760
# 65  Sleep stage N1  6405120
# 67  Sleep stage N2        0
# 68   Sleep stage W   122880
#
# [68 rows x 2 columns]

# %%
file_1.shape
# Out:
# (7, 8877056)

# %%
ex_frame1 = pd.DataFrame()
ex_frame1[['Stage','Onset']]=''
ex_frame1.loc[0]= [file_stage2['description'][0],0]
for i in range(1,len(file_stage2['onset'])):
        ex_frame1.loc[i]= [file_stage2['description'][i],len(file_1[0][int(256*file_stage2['onset'][i-1]):int(256*file_stage2['onset'][i])])+ex_frame1['Onset'][i-1]]
ex_frame1
# Out:
#              Stage    Onset
# 0    Sleep stage W        0
# 1   Sleep stage N1    92160
# 2   Sleep stage N2   115200
# 3   Sleep stage N3   222720
# 4   Sleep stage N2   867840
# ..             ...      ...
# 65  Sleep stage N1  6405120
# 66   Sleep stage ?  6428160
# 67  Sleep stage N2  6435840
# 68   Sleep stage W  6558720
# 69   Sleep stage ?  6566400
#
# [70 rows x 2 columns]

# %%
file_1[0][int(256*file_stage2['onset'][i-1]):int(256*file_stage2['onset'][i])])+ex_frame['Onset'][i-1]]
# Out:
# array([-0.00017746])

# %%
file_a = file_1[0][ex_frame1['Onset'][0]:ex_frame1['Onset'][65]]
file_b = file_1[0][ex_frame1['Onset'][67]:ex_frame1['Onset'][69]]
print(file_a.shape)
print(file_b.shape)
# Out:
# (6405120,)
# (130560,)

# %%
df_a = ex_frame.iloc[0:66,:]
df_b = ex_frame.iloc[66:70,:]
print(df_a)
print(df_b)
# Out:
#              Stage    Onset
# 0    Sleep stage W        0
# 1   Sleep stage N1    92160
# 2   Sleep stage N2   115200
# 3   Sleep stage N3   222720
# 4   Sleep stage N2   867840
# ..             ...      ...
# 61   Sleep stage W  6366720
# 62  Sleep stage N2  6374400
# 63  Sleep stage N1  6382080
# 64  Sleep stage N2  6389760
# 65  Sleep stage N1  6405120
#
# [66 rows x 2 columns]
#              Stage   Onset
# 67  Sleep stage N2       0
# 68   Sleep stage W  122880

# %%
print(ex_frame1[ex_frame1['Stage']=='Sleep stage ?']['Onset'].index+[1])
print(ex_frame1.iloc[ex_frame1[ex_frame1['Stage']=='Sleep stage ?']['Onset'].index+[0],:])
# Out:
# Int64Index([67, 70], dtype='int64')
#             Stage    Onset
# 66  Sleep stage ?  6428160
# 69  Sleep stage ?  6566400

# %%
ex_frame1.iloc[ex_frame1[ex_frame1['Stage']=='Sleep stage ?']['Onset'].index+[0],:]['Onset']
# Out:
# 66    6428160
# 69    6566400
# Name: Onset, dtype: int64

# %%
ex_frame = ex_frame.reset_index()

# %%
# Out:
#     index           Stage    Onset
# 0       0   Sleep stage W        0
# 1       1  Sleep stage N1    92160
# 2       2  Sleep stage N2   115200
# 3       3  Sleep stage N3   222720
# 4       4  Sleep stage N2   867840
# ..    ...             ...      ...
# 63     63  Sleep stage N1  6382080
# 64     64  Sleep stage N2  6389760
# 65     65  Sleep stage N1  6405120
# 67     67  Sleep stage N2        0
# 68     68   Sleep stage W   122880
#
# [68 rows x 3 columns]

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [529], in <cell line: 1>()
# ----> 1 ex_frame.shape
#
# AttributeError: 'NoneType' object has no attribute 'shape'

# %%
file_1[0][int(256*file_stage2['onset'][70-1]):int(256*file_stage2['onset'][70])]= False
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File /usr/local/lib/python3.9/dist-packages/pandas/core/indexes/range.py:385, in RangeIndex.get_loc(self, key, method, tolerance)
#     384 try:
# --> 385     return self._range.index(new_key)
#     386 except ValueError as err:
#
# ValueError: 70 is not in range
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Input In [503], in <cell line: 1>()
# ----> 1 file_1[0][int(256*file_stage2['onset'][70-1]):int(256*file_stage2['onset'][70])]= [False]
#
# File /usr/local/lib/python3.9/dist-packages/pandas/core/series.py:958, in Series.__getitem__(self, key)
#     955     return self._values[key]
#     957 elif key_is_scalar:
# --> 958     return self._get_value(key)
#     960 if is_hashable(key):
#     961     # Otherwise index.get_value will raise InvalidIndexError
#     962     try:
#     963         # For labels that don't resolve as scalars like tuples and frozensets
#
# File /usr/local/lib/python3.9/dist-packages/pandas/core/series.py:1069, in Series._get_value(self, label, takeable)
#    1066     return self._values[label]
#    1068 # Similar to Index.get_value, but we do not fall back to positional
# -> 1069 loc = self.index.get_loc(label)
#    1070 return self.index._get_values_for_loc(self, loc, label)
#
# File /usr/local/lib/python3.9/dist-packages/pandas/core/indexes/range.py:387, in RangeIndex.get_loc(self, key, method, tolerance)
#     385         return self._range.index(new_key)
#     386     except ValueError as err:
# --> 387         raise KeyError(key) from err
#     388 self._check_indexing_error(key)
#     389 raise KeyError(key)
#
# KeyError: 70

# %%
len(file_1[0][int(256*file_stage2['onset'][69-1]):int(256*file_stage2['onset'][69])])
# Out:
# 7680

# %%
ex_frame
# Out:
# {'Stage': 'Sleep stage W', 'Onset': 92160}

# %%
file_1[0][int(256*file_stage2['onset'][0]):int(256*file_stage2['onset'][0+1])].shape

for i in range(len(file_stage2['onset'])):
    print(file_1[0][int(256*file_stage2['onset'][i]):int(256*file_stage2['onset'][i+1])].shape)
# Out:
# (92160,)
# (23040,)
# (107520,)
# (645120,)
# (7680,)
# (99840,)
# (245760,)
# (322560,)
# (184320,)
# (629760,)
# (53760,)
# (161280,)
# (7680,)
# (192000,)
# (15360,)
# (30720,)
# (7680,)
# (376320,)
# (7680,)
# (92160,)
# (161280,)
# (30720,)
# (7680,)
# (7680,)
# (7680,)
# (7680,)
# (7680,)
# (15360,)
# (23040,)
# (7680,)
# (15360,)
# (222720,)
# (7680,)
# (23040,)
# (53760,)
# (15360,)
# (15360,)
# (15360,)
# (376320,)
# (7680,)
# (30720,)
# (7680,)
# (7680,)
# (7680,)
# (76800,)
# (107520,)
# (15360,)
# (7680,)
# (153600,)
# (7680,)
# (245760,)
# (15360,)
# (99840,)
# (23040,)
# (7680,)
# (261120,)
# (261120,)
# (7680,)
# (15360,)
# (483840,)
# (192000,)
# (7680,)
# (7680,)
# (7680,)
# (15360,)
# (23040,)
# (7680,)
# (122880,)
# (7680,)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File /usr/local/lib/python3.9/dist-packages/pandas/core/indexes/range.py:385, in RangeIndex.get_loc(self, key, method, tolerance)
#     384 try:
# --> 385     return self._range.index(new_key)
#     386 except ValueError as err:
#
# ValueError: 70 is not in range
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Input In [398], in <cell line: 3>()
#       1 file_1[0][int(256*file_stage2['onset'][0]):int(256*file_stage2['onset'][0+1])].shape
#       3 for i in range(len(file_stage2['onset'])):
# ----> 4     print(file_1[0][int(256*file_stage2['onset'][i]):int(256*file_stage2['onset'][i+1])].shape)
#
# File /usr/local/lib/python3.9/dist-packages/pandas/core/series.py:958, in Series.__getitem__(self, key)
#     955     return self._values[key]
#     957 elif key_is_scalar:
# --> 958     return self._get_value(key)
#     960 if is_hashable(key):
#     961     # Otherwise index.get_value will raise InvalidIndexError
#     962     try:
#     963         # For labels that don't resolve as scalars like tuples and frozensets
#
# File /usr/local/lib/python3.9/dist-packages/pandas/core/series.py:1069, in Series._get_value(self, label, takeable)
#    1066     return self._values[label]
#    1068 # Similar to Index.get_value, but we do not fall back to positional
# -> 1069 loc = self.index.get_loc(label)
#    1070 return self.index._get_values_for_loc(self, loc, label)
#
# File /usr/local/lib/python3.9/dist-packages/pandas/core/indexes/range.py:387, in RangeIndex.get_loc(self, key, method, tolerance)
#     385         return self._range.index(new_key)
#     386     except ValueError as err:
# --> 387         raise KeyError(key) from err
#     388 self._check_indexing_error(key)
#     389 raise KeyError(key)
#
# KeyError: 70

# %%
ex_frame
# Out:
#        Sleep stage W
# 0        -0.00003977
# 1        -0.00002750
# 2        -0.00001181
# 3        -0.00000540
# 4        -0.00002542
# ...              ...
# 92155    -0.00002518
# 92156    -0.00001279
# 92157    -0.00000528
# 92158     0.00000839
# 92159    -0.00000052
#
# [92160 rows x 1 columns]

# %%
ex_frame = pd.DataFrame()
ex_frame[file_stage2['description'][0]]=file_1[0][int(256*file_stage2['onset'][0]):int(256*file_stage2['onset'][1])]
ex_frame
# Out:
#        Sleep stage W
# 0        -0.00003977
# 1        -0.00002750
# 2        -0.00001181
# 3        -0.00000540
# 4        -0.00002542
# ...              ...
# 92155    -0.00002518
# 92156    -0.00001279
# 92157    -0.00000528
# 92158     0.00000839
# 92159    -0.00000052
#
# [92160 rows x 1 columns]

# %%
file_1.shape
# Out:
# (7, 8877056)

# %%
for i in range(len(file_stage2['description'])):
    if file_stage2['description'][-1]='Sleep stage':
        print('stay')

# %% [markdown]
# file_stage2

# %%
ch_per_rec = {}

for edf in edf_files:
    ch_per_rec[edf] = []
    edfpath = os.path.join(raw_path, edf)
    rawedf = mne.io.read_raw_edf(edfpath)
    ch_per_rec[edf] = rawedf.ch_names
# Out:
# Extracting EDF parameters from /workspace/Competition/PSG/01_DATA/raw/1_4789.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from /workspace/Competition/PSG/01_DATA/raw/10_22339.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from /workspace/Competition/PSG/01_DATA/raw/16_24241.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from /workspace/Competition/PSG/01_DATA/raw/22_23233.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from /workspace/Competition/PSG/01_DATA/raw/25_10579.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from /workspace/Competition/PSG/01_DATA/raw/25_18085.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from /workspace/Competition/PSG/01_DATA/raw/28_15280.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from /workspace/Competition/PSG/01_DATA/raw/31_4429.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from /workspace/Competition/PSG/01_DATA/raw/37_14779.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from /workspace/Competition/PSG/01_DATA/raw/7_12595.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from /workspace/Competition/PSG/01_DATA/raw/40_14503.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from /workspace/Competition/PSG/01_DATA/raw/43_175.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from /workspace/Competition/PSG/01_DATA/raw/46_11305.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from /workspace/Competition/PSG/01_DATA/raw/55_6112.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from /workspace/Competition/PSG/01_DATA/raw/61_19477.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from /workspace/Competition/PSG/01_DATA/raw/64_14908.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from /workspace/Competition/PSG/01_DATA/raw/64_25396.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from /workspace/Competition/PSG/01_DATA/raw/67_5998.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from /workspace/Competition/PSG/01_DATA/raw/70_20743.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from /workspace/Competition/PSG/01_DATA/raw/82_20809.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from /workspace/Competition/PSG/01_DATA/raw/100_23083.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from /workspace/Competition/PSG/01_DATA/raw/103_12325.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from /workspace/Competition/PSG/01_DATA/raw/115_22774.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from /workspace/Competition/PSG/01_DATA/raw/121_23845.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from /workspace/Competition/PSG/01_DATA/raw/127_19126.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from /workspace/Competition/PSG/01_DATA/raw/130_5164.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from /workspace/Competition/PSG/01_DATA/raw/136_4501.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from /workspace/Competition/PSG/01_DATA/raw/91_15028.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from /workspace/Competition/PSG/01_DATA/raw/91_18331.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from /workspace/Competition/PSG/01_DATA/raw/91_3787.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from /workspace/Competition/PSG/01_DATA/raw/139_20275.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from /workspace/Competition/PSG/01_DATA/raw/145_1537.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from /workspace/Competition/PSG/01_DATA/raw/148_568.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from /workspace/Competition/PSG/01_DATA/raw/151_23734.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from /workspace/Competition/PSG/01_DATA/raw/154_18469.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from /workspace/Competition/PSG/01_DATA/raw/157_6391.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from /workspace/Competition/PSG/01_DATA/raw/160_11500.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from /workspace/Competition/PSG/01_DATA/raw/160_12856.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from /workspace/Competition/PSG/01_DATA/raw/160_2740.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from /workspace/Competition/PSG/01_DATA/raw/163_20485.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from /workspace/Competition/PSG/01_DATA/raw/166_10357.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from /workspace/Competition/PSG/01_DATA/raw/181_12274.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from /workspace/Competition/PSG/01_DATA/raw/184_2509.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from /workspace/Competition/PSG/01_DATA/raw/187_6160.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from /workspace/Competition/PSG/01_DATA/raw/190_9877.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from /workspace/Competition/PSG/01_DATA/raw/202_13666.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from /workspace/Competition/PSG/01_DATA/raw/205_23176.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from /workspace/Competition/PSG/01_DATA/raw/211_25741.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from /workspace/Competition/PSG/01_DATA/raw/211_8290.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Extracting EDF parameters from /workspace/Competition/PSG/01_DATA/raw/220_7708.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...

# %%
ch_per_rec
# Out:
# {'1_4789.edf': ['Patient Event',
#   'EOG LOC-M2',
#   'EOG ROC-M1',
#   'EMG Chin1-Chin2',
#   'EEG F3-M2',
#   'EEG F4-M1',
#   'EEG C3-M2',
#   'EEG C4-M1',
#   'EEG O1-M2',
#   'EEG O2-M1',
#   'EEG CZ-O1',
#   'EMG LLeg-RLeg',
#   'ECG EKG2-EKG',
#   'Snore',
#   'Resp PTAF',
#   'Resp Airflow',
#   'Resp Thoracic',
#   'Resp Abdominal',
#   'SpO2',
#   'Rate',
#   'EtCO2',
#   'Capno',
#   'Resp Rate',
#   'C-flow',
#   'Tidal Vol',
#   'Pressure'],
#  '10_22339.edf': ['Patient Event',
#   'EOG LOC-M2',
#   'EOG ROC-M1',
#   'EMG Chin1-Chin2',
#   'EEG F3-M2',
#   'EEG F4-M1',
#   'EEG C3-M2',
#   'EEG C4-M1',
#   'EEG O1-M2',
#   'EEG O2-M1',
#   'EEG CZ-O1',
#   'EMG LLeg-RLeg',
#   'ECG EKG2-EKG',
#   'Snore',
#   'Resp PTAF',
#   'Resp Airflow',
#   'Resp Thoracic',
#   'Resp Abdominal',
#   'SpO2',
#   'Rate',
#   'EtCO2',
#   'Capno',
#   'Resp Rate',
#   'C-flow',
#   'Tidal Vol',
#   'Pressure'],
#  '16_24241.edf': ['Patient Event',
#   'EOG LOC-M2',
#   'EOG ROC-M1',
#   'EMG Chin1-Chin2',
#   'EEG F3-M2',
#   'EEG F4-M1',
#   'EEG C3-M2',
#   'EEG C4-M1',
#   'EEG O1-M2',
#   'EEG O2-M1',
#   'EEG CZ-O1',
#   'EMG LLeg-RLeg',
#   'ECG EKG2-EKG',
#   'Snore',
#   'Resp PTAF',
#   'Resp Airflow',
#   'Resp Thoracic',
#   'Resp Abdominal',
#   'SpO2',
#   'Rate',
#   'EtCO2',
#   'Capno',
#   'Resp Rate',
#   'C-flow',
#   'Tidal Vol',
#   'Pressure'],
#  '22_23233.edf': ['Patient Event',
#   'EOG LOC-M2',
#   'EOG ROC-M1',
#   'EMG CHIN1-CHIN2',
#   'EEG F3-M2',
#   'EEG F4-M1',
#   'EEG C3-M2',
#   'EEG C4-M1',
#   'EEG O1-M2',
#   'EEG O2-M1',
#   'EEG Cz-O1',
#   'EMG LLEG+-LLEG-',
#   'EMG RLEG+-RLEG-',
#   'ECG LA-RA',
#   'Snore',
#   'Snore_DR',
#   'Flow_DR',
#   'Resp Flow',
#   'XFlow',
#   'Resp Chest',
#   'Resp Abdomen',
#   'OSAT',
#   'Rate',
#   'EtCO2',
#   'Capno',
#   'Resp Rate',
#   'TcCO2',
#   'C-Flow',
#   'C-Pressure'],
#  '25_10579.edf': ['Patient Event',
#   'EOG LOC-M2',
#   'EOG ROC-M1',
#   'EMG CHIN1-CHIN2',
#   'EEG F3-M2',
#   'EEG F4-M1',
#   'EEG C3-M2',
#   'EEG C4-M1',
#   'EEG O1-M2',
#   'EEG O2-M1',
#   'EEG Cz-O1',
#   'EMG LLEG+-LLEG-',
#   'EMG RLEG+-RLEG-',
#   'ECG LA-RA',
#   'Snore',
#   'Snore_DR',
#   'Flow_DR',
#   'Resp Flow',
#   'XFlow',
#   'Resp Chest',
#   'Resp Abdomen',
#   'OSAT',
#   'Rate',
#   'EtCO2',
#   'Capno',
#   'Resp Rate',
#   'TcCO2',
#   'C-Flow',
#   'C-Pressure'],
#  '25_18085.edf': ['Patient Event',
#   'EOG LOC-M2',
#   'EOG ROC-M1',
#   'EMG Chin1-Chin2',
#   'EEG F3-M2',
#   'EEG F4-M1',
#   'EEG C3-M2',
#   'EEG C4-M1',
#   'EEG O1-M2',
#   'EEG O2-M1',
#   'EEG CZ-O1',
#   'EMG LLeg-RLeg',
#   'ECG EKG2-EKG',
#   'Snore',
#   'Resp PTAF',
#   'Resp Airflow',
#   'Resp Thoracic',
#   'Resp Abdominal',
#   'SpO2',
#   'Rate',
#   'EtCO2',
#   'Capno',
#   'Resp Rate',
#   'C-flow',
#   'Tidal Vol',
#   'Pressure'],
#  '28_15280.edf': ['Patient Event',
#   'EOG LOC-M2',
#   'EOG ROC-M1',
#   'EMG CHIN1-CHIN2',
#   'EEG F3-M2',
#   'EEG F4-M1',
#   'EEG C3-M2',
#   'EEG C4-M1',
#   'EEG O1-M2',
#   'EEG O2-M1',
#   'EEG Cz-O1',
#   'EMG LLEG+-LLEG-',
#   'EMG RLEG+-RLEG-',
#   'ECG LA-RA',
#   'Snore',
#   'Snore_DR',
#   'Flow_DR',
#   'Resp Flow',
#   'XFlow',
#   'Resp Chest',
#   'Resp Abdomen',
#   'OSAT',
#   'Rate',
#   'EtCO2',
#   'Capno',
#   'Resp Rate',
#   'TcCO2',
#   'C-Flow',
#   'C-Pressure'],
#  '31_4429.edf': ['Patient Event',
#   'EOG LOC-M2',
#   'EOG ROC-M1',
#   'EMG CHIN1-CHIN2',
#   'EEG F3-M2',
#   'EEG F4-M1',
#   'EEG C3-M2',
#   'EEG C4-M1',
#   'EEG O1-M2',
#   'EEG O2-M1',
#   'EEG Cz-O1',
#   'EMG LLEG+-LLEG-',
#   'EMG RLEG+-RLEG-',
#   'ECG LA-RA',
#   'Snore',
#   'Snore_DR',
#   'Flow_DR',
#   'Resp Flow',
#   'XFlow',
#   'Resp Chest',
#   'Resp Abdomen',
#   'OSAT',
#   'Rate',
#   'EtCO2',
#   'Capno',
#   'Resp Rate',
#   'TcCO2',
#   'C-Flow',
#   'C-Pressure'],
#  '37_14779.edf': ['Patient Event',
#   'EOG LOC-M2',
#   'EOG ROC-M1',
#   'EMG Chin1-Chin2',
#   'EEG F3-M2',
#   'EEG F4-M1',
#   'EEG C3-M2',
#   'EEG C4-M1',
#   'EEG O1-M2',
#   'EEG O2-M1',
#   'EEG CZ-O1',
#   'EMG LLeg-RLeg',
#   'ECG EKG2-EKG',
#   'Snore',
#   'Resp PTAF',
#   'Resp Airflow',
#   'Resp Thoracic',
#   'Resp Abdominal',
#   'SpO2',
#   'Rate',
#   'EtCO2',
#   'Capno',
#   'Resp Rate',
#   'C-flow',
#   'Tidal Vol',
#   'Pressure'],
#  '7_12595.edf': ['Patient Event',
#   'EOG LOC-M2',
#   'EOG ROC-M1',
#   'EMG Chin1-Chin2',
#   'EEG F3-M2',
#   'EEG F4-M1',
#   'EEG C3-M2',
#   'EEG C4-M1',
#   'EEG O1-M2',
#   'EEG O2-M1',
#   'EEG CZ-O1',
#   'EMG LLeg-RLeg',
#   'ECG EKG2-EKG',
#   'Snore',
#   'Resp PTAF',
#   'Resp Airflow',
#   'Resp Thoracic',
#   'Resp Abdominal',
#   'SpO2',
#   'Rate',
#   'EtCO2',
#   'Capno',
#   'Resp Rate',
#   'C-flow',
#   'Tidal Vol',
#   'Pressure'],
#  '40_14503.edf': ['EOG LOC-M2',
#   'EOG ROC-M1',
#   'EMG Chin1-Chin2',
#   'EEG F3-M2',
#   'EEG F4-M1',
#   'EEG C3-M2',
#   'EEG C4-M1',
#   'EEG O1-M2',
#   'EEG O2-M1',
#   'EEG CZ-O1',
#   'EMG LLeg-RLeg',
#   'ECG EKG2-EKG',
#   'Snore',
#   'Resp PTAF',
#   'Resp Airflow',
#   'Resp Thoracic',
#   'Resp Abdominal',
#   'SpO2',
#   'Rate',
#   'EtCO2',
#   'Capno',
#   'Resp Rate',
#   'C-flow',
#   'Tidal Vol',
#   'Pressure'],
#  '43_175.edf': ['Patient Event',
#   'EOG LOC-M2',
#   'EOG ROC-M1',
#   'EMG Chin1-Chin2',
#   'EEG F3-M2',
#   'EEG F4-M1',
#   'EEG C3-M2',
#   'EEG C4-M1',
#   'EEG O1-M2',
#   'EEG O2-M1',
#   'EEG CZ-O1',
#   'EMG LLeg-RLeg',
#   'ECG EKG2-EKG',
#   'Snore',
#   'Resp PTAF',
#   'Resp Airflow',
#   'Resp Thoracic',
#   'Resp Abdominal',
#   'SpO2',
#   'Rate',
#   'EtCO2',
#   'Capno',
#   'Resp Rate',
#   'C-flow',
#   'Tidal Vol',
#   'Pressure'],
#  '46_11305.edf': ['Patient Event',
#   'EOG LOC-M2',
#   'EOG ROC-M1',
#   'EMG Chin1-Chin2',
#   'EEG F3-M2',
#   'EEG F4-M1',
#   'EEG C3-M2',
#   'EEG C4-M1',
#   'EEG O1-M2',
#   'EEG O2-M1',
#   'EEG CZ-O1',
#   'EMG LLeg-RLeg',
#   'ECG EKG2-EKG',
#   'Snore',
#   'Resp PTAF',
#   'Resp Airflow',
#   'Resp Thoracic',
#   'Resp Abdominal',
#   'SpO2',
#   'Rate',
#   'EtCO2',
#   'Capno',
#   'Resp Rate',
#   'C-flow',
#   'Tidal Vol',
#   'Pressure'],
#  '55_6112.edf': ['Patient Event',
#   'EOG LOC-M2',
#   'EOG ROC-M1',
#   'EMG Chin1-Chin2',
#   'EEG F3-M2',
#   'EEG F4-M1',
#   'EEG C3-M2',
#   'EEG C4-M1',
#   'EEG O1-M2',
#   'EEG O2-M1',
#   'EEG CZ-O1',
#   'EMG LLeg-RLeg',
#   'ECG EKG2-EKG',
#   'Snore',
#   'Resp PTAF',
#   'Resp Airflow',
#   'Resp Thoracic',
#   'Resp Abdominal',
#   'SpO2',
#   'Rate',
#   'EtCO2',
#   'Capno',
#   'Resp Rate',
#   'C-flow',
#   'Tidal Vol',
#   'Pressure'],
#  '61_19477.edf': ['EOG LOC-M2',
#   'EOG ROC-M1',
#   'EMG Chin1-Chin2',
#   'EEG F3-M2',
#   'EEG F4-M1',
#   'EEG C3-M2',
#   'EEG C4-M1',
#   'EEG O1-M2',
#   'EEG O2-M1',
#   'EEG CZ-O1',
#   'EMG LLeg-RLeg',
#   'ECG EKG2-EKG',
#   'Snore',
#   'Resp PTAF',
#   'Resp Airflow',
#   'Resp Thoracic',
#   'Resp Abdominal',
#   'SpO2',
#   'Rate',
#   'EtCO2',
#   'Capno',
#   'Resp Rate',
#   'C-flow',
#   'Tidal Vol',
#   'Pressure'],
#  '64_14908.edf': ['Patient Event',
#   'EOG LOC-M2',
#   'EOG ROC-M1',
#   'EMG Chin1-Chin2',
#   'EEG F3-M2',
#   'EEG F4-M1',
#   'EEG C3-M2',
#   'EEG C4-M1',
#   'EEG O1-M2',
#   'EEG O2-M1',
#   'EEG CZ-O1',
#   'EMG LLeg-RLeg',
#   'ECG EKG2-EKG',
#   'Snore',
#   'Resp PTAF',
#   'Resp Airflow',
#   'Resp Thoracic',
#   'Resp Abdominal',
#   'SpO2',
#   'Rate',
#   'EtCO2',
#   'Capno',
#   'Resp Rate',
#   'C-flow',
#   'Tidal Vol',
#   'Pressure'],
#  '64_25396.edf': ['Patient Event',
#   'EOG LOC-M2',
#   'EOG ROC-M1',
#   'EMG Chin1-Chin2',
#   'EEG F3-M2',
#   'EEG F4-M1',
#   'EEG C3-M2',
#   'EEG C4-M1',
#   'EEG O1-M2',
#   'EEG O2-M1',
#   'EEG CZ-O1',
#   'EMG LLeg-RLeg',
#   'ECG EKG2-EKG',
#   'Snore',
#   'Resp PTAF',
#   'Resp Airflow',
#   'Resp Thoracic',
#   'Resp Abdominal',
#   'SpO2',
#   'Rate',
#   'EtCO2',
#   'Capno',
#   'Resp Rate',
#   'C-flow',
#   'Tidal Vol',
#   'Pressure'],
#  '67_5998.edf': ['Patient Event',
#   'EOG LOC-M2',
#   'EOG ROC-M1',
#   'EMG Chin1-Chin2',
#   'EEG F3-M2',
#   'EEG F4-M1',
#   'EEG C3-M2',
#   'EEG C4-M1',
#   'EEG O1-M2',
#   'EEG O2-M1',
#   'EEG CZ-O1',
#   'EMG LLeg-RLeg',
#   'ECG EKG2-EKG',
#   'Snore',
#   'Resp PTAF',
#   'Resp Airflow',
#   'Resp Thoracic',
#   'Resp Abdominal',
#   'SpO2',
#   'Rate',
#   'EtCO2',
#   'Capno',
#   'Resp Rate',
#   'C-flow',
#   'Tidal Vol',
#   'Pressure'],
#  '70_20743.edf': ['EOG LOC-M2',
#   'EOG ROC-M1',
#   'EMG Chin2-Chin1',
#   'EEG F3-M2',
#   'EEG F4-M1',
#   'EEG C3-M2',
#   'EEG C4-M1',
#   'EEG O1-M2',
#   'EEG O2-M1',
#   'EEG CZ-O1',
#   'EMG LLeg-RLeg',
#   'ECG EKG2-EKG',
#   'Snore',
#   'Resp PTAF',
#   'Resp Airflow',
#   'Resp Thoracic',
#   'Resp Abdominal',
#   'SpO2',
#   'Rate',
#   'EtCO2',
#   'Capno',
#   'Resp Rate',
#   'C-flow',
#   'Tidal Vol',
#   'Pressure'],
#  '82_20809.edf': ['Patient Event',
#   'EOG LOC-M2',
#   'EOG ROC-M1',
#   'EMG CHIN1-CHIN2',
#   'EEG F3-M2',
#   'EEG F4-M1',
#   'EEG C3-M2',
#   'EEG C4-M1',
#   'EEG O1-M2',
#   'EEG O2-M1',
#   'EEG Cz-O1',
#   'EMG LLEG+-LLEG-',
#   'EMG RLEG+-RLEG-',
#   'ECG LA-RA',
#   'Snore',
#   'Snore_DR',
#   'Flow_DR',
#   'Resp Flow',
#   'XFlow',
#   'Resp Chest',
#   'Resp Abdomen',
#   'OSAT',
#   'Rate',
#   'EtCO2',
#   'Capno',
#   'Resp Rate',
#   'TcCO2',
#   'C-Flow',
#   'C-Pressure'],
#  '100_23083.edf': ['Patient Event',
#   'EOG LOC-M2',
#   'EOG ROC-M1',
#   'EMG Chin1-Chin2',
#   'EEG F3-M2',
#   'EEG F4-M1',
#   'EEG C3-M2',
#   'EEG C4-M1',
#   'EEG O1-M2',
#   'EEG O2-M1',
#   'EEG CZ-O1',
#   'EMG LLeg-RLeg',
#   'ECG EKG2-EKG',
#   'Snore',
#   'Resp PTAF',
#   'Resp Airflow',
#   'Resp Thoracic',
#   'Resp Abdominal',
#   'SpO2',
#   'Rate',
#   'EtCO2',
#   'Capno',
#   'Resp Rate',
#   'C-flow',
#   'Tidal Vol',
#   'Pressure'],
#  '103_12325.edf': ['Patient Event',
#   'EOG LOC-M2',
#   'EOG ROC-M1',
#   'EMG Chin1-Chin2',
#   'EEG F3-M2',
#   'EEG F4-M1',
#   'EEG C3-M2',
#   'EEG C4-M1',
#   'EEG O1-M2',
#   'EEG O2-M1',
#   'EEG CZ-O1',
#   'EMG LLeg-RLeg',
#   'ECG EKG2-EKG',
#   'Snore',
#   'Resp PTAF',
#   'Resp Airflow',
#   'Resp Thoracic',
#   'Resp Abdominal',
#   'SpO2',
#   'Rate',
#   'EtCO2',
#   'Capno',
#   'Resp Rate',
#   'C-flow',
#   'Tidal Vol',
#   'Pressure'],
#  '115_22774.edf': ['Patient Event',
#   'EOG LOC-M2',
#   'EOG ROC-M1',
#   'EMG Chin1-Chin2',
#   'EEG F3-M2',
#   'EEG F4-M1',
#   'EEG C3-M2',
#   'EEG C4-M1',
#   'EEG O1-M2',
#   'EEG O2-M1',
#   'EEG CZ-O1',
#   'EMG LLeg-RLeg',
#   'ECG EKG2-EKG',
#   'Snore',
#   'Resp PTAF',
#   'Resp Airflow',
#   'Resp Thoracic',
#   'Resp Abdominal',
#   'SpO2',
#   'Rate',
#   'EtCO2',
#   'Capno',
#   'Resp Rate',
#   'C-flow',
#   'Tidal Vol',
#   'Pressure'],
#  '121_23845.edf': ['Patient Event',
#   'EOG LOC-M2',
#   'EOG ROC-M1',
#   'EMG CHIN1-CHIN2',
#   'EEG F3-M2',
#   'EEG F4-M1',
#   'EEG C3-M2',
#   'EEG C4-M1',
#   'EEG O1-M2',
#   'EEG O2-M1',
#   'EEG Cz-O1',
#   'EMG LLEG+-LLEG-',
#   'EMG RLEG+-RLEG-',
#   'ECG LA-RA',
#   'Snore',
#   'Snore_DR',
#   'Flow_DR',
#   'Resp Flow',
#   'XFlow',
#   'Resp Chest',
#   'Resp Abdomen',
#   'OSAT',
#   'Rate',
#   'EtCO2',
#   'Capno',
#   'Resp Rate',
#   'TcCO2',
#   'C-Flow',
#   'C-Pressure'],
#  '127_19126.edf': ['Patient Event',
#   'EOG LOC-M2',
#   'EOG ROC-M1',
#   'EMG Chin1-Chin2',
#   'EEG F3-M2',
#   'EEG F4-M1',
#   'EEG C3-M2',
#   'EEG C4-M1',
#   'EEG O1-M2',
#   'EEG O2-M1',
#   'EEG CZ-O1',
#   'EMG LLeg-RLeg',
#   'ECG EKG2-EKG',
#   'Snore',
#   'Resp PTAF',
#   'Resp Airflow',
#   'Resp Thoracic',
#   'Resp Abdominal',
#   'SpO2',
#   'Rate',
#   'EtCO2',
#   'Capno',
#   'Resp Rate',
#   'C-flow',
#   'Tidal Vol',
#   'Pressure'],
#  '130_5164.edf': ['EOG LOC-M2',
#   'EOG ROC-M1',
#   'EMG Chin1-Chin2',
#   'EEG F3-M2',
#   'EEG F4-M1',
#   'EEG C3-M2',
#   'EEG C4-M1',
#   'EEG O1-M2',
#   'EEG O2-M1',
#   'EEG CZ-O1',
#   'EMG LLeg-RLeg',
#   'ECG EKG2-EKG',
#   'Snore',
#   'Resp PTAF',
#   'Resp Airflow',
#   'Resp Thoracic',
#   'Resp Abdominal',
#   'SpO2',
#   'Rate',
#   'EtCO2',
#   'TcCO2',
#   'Capno',
#   'Resp Rate',
#   'C-flow',
#   'Tidal Vol',
#   'Pressure'],
#  '136_4501.edf': ['Patient Event',
#   'EOG LOC-M2',
#   'EOG ROC-M1',
#   'EMG Chin1-Chin2',
#   'EEG F3-M2',
#   'EEG F4-M1',
#   'EEG C3-M2',
#   'EEG C4-M1',
#   'EEG O1-M2',
#   'EEG O2-M1',
#   'EEG CZ-O1',
#   'EMG LLeg-RLeg',
#   'ECG EKG2-EKG',
#   'Snore',
#   'Resp PTAF',
#   'Resp Airflow',
#   'Resp Thoracic',
#   'Resp Abdominal',
#   'SpO2',
#   'Rate',
#   'EtCO2',
#   'Capno',
#   'Resp Rate',
#   'C-flow',
#   'Tidal Vol',
#   'Pressure'],
#  '91_15028.edf': ['Patient Event',
#   'EOG LOC-M2',
#   'EOG ROC-M1',
#   'EMG Chin1-Chin2',
#   'EEG F3-M2',
#   'EEG F4-M1',
#   'EEG C3-M2',
#   'EEG C4-M1',
#   'EEG O1-M2',
#   'EEG O2-M1',
#   'EEG CZ-O1',
#   'EMG LLeg-RLeg',
#   'ECG EKG2-EKG',
#   'Snore',
#   'Resp PTAF',
#   'Resp Airflow',
#   'Resp Thoracic',
#   'Resp Abdominal',
#   'SpO2',
#   'Rate',
#   'EtCO2',
#   'Capno',
#   'Resp Rate',
#   'C-flow',
#   'Tidal Vol',
#   'Pressure'],
#  '91_18331.edf': ['Patient Event',
#   'EOG LOC-M2',
#   'EOG ROC-M1',
#   'EMG Chin1-Chin2',
#   'EEG F3-M2',
#   'EEG F4-M1',
#   'EEG C3-M2',
#   'EEG C4-M1',
#   'EEG O1-M2',
#   'EEG O2-M1',
#   'EEG CZ-O1',
#   'EMG LLeg-RLeg',
#   'ECG EKG2-EKG',
#   'Snore',
#   'Resp PTAF',
#   'Resp Airflow',
#   'Resp Thoracic',
#   'Resp Abdominal',
#   'SpO2',
#   'Rate',
#   'EtCO2',
#   'Capno',
#   'Resp Rate',
#   'C-flow',
#   'Tidal Vol',
#   'Pressure'],
#  '91_3787.edf': ['Patient Event',
#   'EOG LOC-M2',
#   'EOG ROC-M1',
#   'EMG Chin1-Chin2',
#   'EEG F3-M2',
#   'EEG F4-M1',
#   'EEG C3-M2',
#   'EEG C4-M1',
#   'EEG O1-M2',
#   'EEG O2-M1',
#   'EEG CZ-O1',
#   'EMG LLeg-RLeg',
#   'ECG EKG2-EKG',
#   'Snore',
#   'Resp PTAF',
#   'Resp Airflow',
#   'Resp Thoracic',
#   'Resp Abdominal',
#   'SpO2',
#   'Rate',
#   'EtCO2',
#   'Capno',
#   'Resp Rate',
#   'C-flow',
#   'Tidal Vol',
#   'Pressure'],
#  '139_20275.edf': ['Patient Event',
#   'EOG LOC-M2',
#   'EOG ROC-M1',
#   'EMG Chin1-Chin2',
#   'EEG F3-M2',
#   'EEG F4-M1',
#   'EEG C3-M2',
#   'EEG C4-M1',
#   'EEG O1-M2',
#   'EEG O2-M1',
#   'EEG CZ-O1',
#   'EMG LLeg-RLeg',
#   'ECG EKG2-EKG',
#   'Snore',
#   'Resp PTAF',
#   'Resp Airflow',
#   'Resp Thoracic',
#   'Resp Abdominal',
#   'SpO2',
#   'Rate',
#   'EtCO2',
#   'Capno',
#   'Resp Rate',
#   'C-flow',
#   'Tidal Vol',
#   'Pressure'],
#  '145_1537.edf': ['Patient Event',
#   'EOG LOC-M2',
#   'EOG ROC-M1',
#   'EMG Chin1-Chin2',
#   'EEG F3-M2',
#   'EEG F4-M1',
#   'EEG C3-M2',
#   'EEG C4-M1',
#   'EEG O1-M2',
#   'EEG O2-M1',
#   'EEG CZ-O1',
#   'EMG LLeg-RLeg',
#   'ECG EKG2-EKG',
#   'Snore',
#   'Resp PTAF',
#   'Resp Airflow',
#   'Resp Thoracic',
#   'Resp Abdominal',
#   'SpO2',
#   'Rate',
#   'EtCO2',
#   'Capno',
#   'Resp Rate',
#   'C-flow',
#   'Tidal Vol',
#   'Pressure'],
#  '148_568.edf': ['Patient Event',
#   'EOG LOC-M2',
#   'EOG ROC-M1',
#   'EMG Chin1-Chin2',
#   'EEG F3-M2',
#   'EEG F4-M1',
#   'EEG C3-M2',
#   'EEG C4-M1',
#   'EEG O1-M2',
#   'EEG O2-M1',
#   'EEG CZ-O1',
#   'EMG LLeg-RLeg',
#   'ECG EKG2-EKG',
#   'Snore',
#   'Resp PTAF',
#   'Resp Airflow',
#   'Resp Thoracic',
#   'Resp Abdominal',
#   'SpO2',
#   'Rate',
#   'EtCO2',
#   'Capno',
#   'Resp Rate',
#   'C-flow',
#   'Tidal Vol',
#   'Pressure'],
#  '151_23734.edf': ['EOG LOC-M2',
#   'EOG ROC-M1',
#   'EMG Chin1-Chin2',
#   'EEG F3-M2',
#   'EEG F4-M1',
#   'EEG C3-M2',
#   'EEG C4-M1',
#   'EEG O1-M2',
#   'EEG O2-M1',
#   'EEG CZ-O1',
#   'EMG LLeg-RLeg',
#   'ECG EKG2-EKG',
#   'Snore',
#   'Resp PTAF',
#   'Resp Airflow',
#   'Resp Thoracic',
#   'Resp Abdominal',
#   'SpO2',
#   'Rate',
#   'EtCO2',
#   'Capno',
#   'Resp Rate',
#   'C-flow',
#   'Tidal Vol',
#   'Pressure'],
#  '154_18469.edf': ['Patient Event',
#   'EOG LOC-M2',
#   'EOG ROC-M1',
#   'EMG CHIN1-CHIN2',
#   'EEG F3-M2',
#   'EEG F4-M1',
#   'EEG C3-M2',
#   'EEG C4-M1',
#   'EEG O1-M2',
#   'EEG O2-M1',
#   'EEG Cz-O1',
#   'EMG LLEG+-LLEG-',
#   'EMG RLEG+-RLEG-',
#   'ECG LA-RA',
#   'Snore',
#   'Snore_DR',
#   'Flow_DR',
#   'Resp Flow',
#   'XFlow',
#   'Resp Chest',
#   'Resp Abdomen',
#   'OSAT',
#   'Rate',
#   'EtCO2',
#   'Capno',
#   'Resp Rate',
#   'TcCO2',
#   'C-Flow',
#   'C-Pressure'],
#  '157_6391.edf': ['Patient Event',
#   'EOG LOC-M2',
#   'EOG ROC-M1',
#   'EMG Chin1-Chin2',
#   'EEG F3-M2',
#   'EEG F4-M1',
#   'EEG C3-M2',
#   'EEG C4-M1',
#   'EEG O1-M2',
#   'EEG O2-M1',
#   'EEG CZ-O1',
#   'EMG LLeg-RLeg',
#   'ECG EKG2-EKG',
#   'Snore',
#   'Resp PTAF',
#   'Resp Airflow',
#   'Resp Thoracic',
#   'Resp Abdominal',
#   'SpO2',
#   'Rate',
#   'EtCO2',
#   'Capno',
#   'Resp Rate',
#   'C-flow',
#   'Tidal Vol',
#   'Pressure'],
#  '160_11500.edf': ['Patient Event',
#   'EOG LOC-M2',
#   'EOG ROC-M1',
#   'EMG Chin1-Chin2',
#   'EEG F3-M2',
#   'EEG F4-M1',
#   'EEG C3-M2',
#   'EEG C4-M1',
#   'EEG O1-M2',
#   'EEG O2-M1',
#   'EEG CZ-O1',
#   'EMG LLeg-RLeg',
#   'ECG EKG2-EKG',
#   'Snore',
#   'Resp PTAF',
#   'Resp Airflow',
#   'Resp Thoracic',
#   'Resp Abdominal',
#   'SpO2',
#   'Rate',
#   'EtCO2',
#   'Capno',
#   'Resp Rate',
#   'C-flow',
#   'Tidal Vol',
#   'Pressure'],
#  '160_12856.edf': ['Patient Event',
#   'EOG LOC-M2',
#   'EOG ROC-M1',
#   'EMG Chin1-Chin2',
#   'EEG F3-M2',
#   'EEG F4-M1',
#   'EEG C3-M2',
#   'EEG C4-M1',
#   'EEG O1-M2',
#   'EEG O2-M1',
#   'EEG CZ-O1',
#   'EMG LLeg-RLeg',
#   'ECG EKG2-EKG',
#   'Snore',
#   'Resp PTAF',
#   'Resp Airflow',
#   'Resp Thoracic',
#   'Resp Abdominal',
#   'SpO2',
#   'Rate',
#   'EtCO2',
#   'Capno',
#   'Resp Rate',
#   'C-flow',
#   'Tidal Vol',
#   'Pressure'],
#  '160_2740.edf': ['EOG LOC-M2',
#   'EOG ROC-M1',
#   'EMG Chin1-Chin2',
#   'EEG F3-M2',
#   'EEG F4-M1',
#   'EEG C3-M2',
#   'EEG C4-M1',
#   'EEG O1-M2',
#   'EEG O2-M1',
#   'EEG CZ-O1',
#   'EMG LLeg-RLeg',
#   'ECG EKG2-EKG',
#   'Snore',
#   'Resp PTAF',
#   'Resp Airflow',
#   'Resp Thoracic',
#   'Resp Abdominal',
#   'SpO2',
#   'Rate',
#   'EtCO2',
#   'Capno',
#   'Resp Rate',
#   'C-flow',
#   'Tidal Vol',
#   'Pressure'],
#  '163_20485.edf': ['Patient Event',
#   'EOG LOC-M2',
#   'EOG ROC-M1',
#   'EMG CHIN1-CHIN2',
#   'EEG F3-M2',
#   'EEG F4-M1',
#   'EEG C3-M2',
#   'EEG C4-M1',
#   'EEG O1-M2',
#   'EEG O2-M1',
#   'EEG Cz-O1',
#   'EMG LLEG+-LLEG-',
#   'EMG RLEG+-RLEG-',
#   'ECG LA-RA',
#   'Snore',
#   'Snore_DR',
#   'Flow_DR',
#   'Resp Flow',
#   'XFlow',
#   'Resp Chest',
#   'Resp Abdomen',
#   'OSAT',
#   'Rate',
#   'EtCO2',
#   'Capno',
#   'Resp Rate',
#   'TcCO2',
#   'C-Flow',
#   'C-Pressure'],
#  '166_10357.edf': ['Patient Event',
#   'EOG LOC-M2',
#   'EOG ROC-M1',
#   'EMG CHIN1-CHIN2',
#   'EEG F3-M2',
#   'EEG F4-M1',
#   'EEG C3-M2',
#   'EEG C4-M1',
#   'EEG O1-M2',
#   'EEG O2-M1',
#   'EEG Cz-O1',
#   'EMG LLEG+-LLEG-',
#   'EMG RLEG+-RLEG-',
#   'ECG LA-RA',
#   'Snore',
#   'Snore_DR',
#   'Flow_DR',
#   'Resp Flow',
#   'XFlow',
#   'Resp Chest',
#   'Resp Abdomen',
#   'OSAT',
#   'Rate',
#   'EtCO2',
#   'Capno',
#   'Resp Rate',
#   'TcCO2',
#   'C-Flow',
#   'C-Pressure'],
#  '181_12274.edf': ['Patient Event',
#   'EOG LOC-M2',
#   'EOG ROC-M1',
#   'EMG Chin1-Chin2',
#   'EEG F3-M2',
#   'EEG F4-M1',
#   'EEG C3-M2',
#   'EEG C4-M1',
#   'EEG O1-M2',
#   'EEG O2-M1',
#   'EEG CZ-O1',
#   'EMG LLeg-RLeg',
#   'ECG EKG2-EKG',
#   'Snore',
#   'Resp PTAF',
#   'Resp Airflow',
#   'Resp Thoracic',
#   'Resp Abdominal',
#   'SpO2',
#   'Rate',
#   'EtCO2',
#   'Capno',
#   'Resp Rate',
#   'C-flow',
#   'Tidal Vol',
#   'Pressure'],
#  '184_2509.edf': ['Patient Event',
#   'EOG LOC-M2',
#   'EOG ROC-M1',
#   'EMG Chin1-Chin2',
#   'EEG F3-M2',
#   'EEG F4-M1',
#   'EEG C3-M2',
#   'EEG C4-M1',
#   'EEG O1-M2',
#   'EEG O2-M1',
#   'EEG CZ-O1',
#   'EMG LLeg-RLeg',
#   'ECG EKG2-EKG',
#   'Snore',
#   'Resp PTAF',
#   'Resp Airflow',
#   'Resp Thoracic',
#   'Resp Abdominal',
#   'SpO2',
#   'Rate',
#   'EtCO2',
#   'Capno',
#   'Resp Rate',
#   'C-flow',
#   'Tidal Vol',
#   'Pressure'],
#  '187_6160.edf': ['Patient Event',
#   'EOG LOC-M2',
#   'EOG ROC-M1',
#   'EMG Chin1-Chin2',
#   'EEG F3-M2',
#   'EEG F4-M1',
#   'EEG C3-M2',
#   'EEG C4-M1',
#   'EEG O1-M2',
#   'EEG O2-M1',
#   'EEG CZ-O1',
#   'EMG LLeg-RLeg',
#   'ECG EKG2-EKG',
#   'Snore',
#   'Resp PTAF',
#   'Resp Airflow',
#   'Resp Thoracic',
#   'Resp Abdominal',
#   'SpO2',
#   'Rate',
#   'EtCO2',
#   'Capno',
#   'Resp Rate',
#   'C-flow',
#   'Tidal Vol',
#   'Pressure'],
#  '190_9877.edf': ['EOG LOC-M2',
#   'EOG ROC-M1',
#   'EEG Chin3-Chin2',
#   'EEG F3-M2',
#   'EEG F4-M1',
#   'EEG C3-M2',
#   'EEG C4-M1',
#   'EEG O1-M2',
#   'EEG O2-M1',
#   'EEG CZ-O1',
#   'EMG LLeg-RLeg',
#   'ECG EKG2-EKG',
#   'Snore',
#   'Resp PTAF',
#   'Resp Airflow',
#   'Resp Thoracic',
#   'Resp Abdominal',
#   'SpO2',
#   'Rate',
#   'EtCO2',
#   'Capno',
#   'Resp Rate',
#   'C-flow',
#   'Tidal Vol',
#   'Pressure'],
#  '202_13666.edf': ['EOG LOC-M2',
#   'EOG ROC-M1',
#   'EMG CHIN1-CHIN2',
#   'EEG F3-M2',
#   'EEG F4-M1',
#   'EEG C3-M2',
#   'EEG C4-M1',
#   'EEG O1-M2',
#   'EEG O2-M1',
#   'EEG Cz-O1',
#   'EMG LLEG+-LLEG-',
#   'EMG RLEG+-RLEG-',
#   'ECG LA-RA',
#   'Snore',
#   'Snore_DR',
#   'Flow_DR',
#   'Resp Flow',
#   'XFlow',
#   'Resp Chest',
#   'Resp Abdomen',
#   'OSAT',
#   'Rate',
#   'EtCO2',
#   'Capno',
#   'Resp Rate',
#   'TcCO2',
#   'C-Flow',
#   'C-Pressure'],
#  '205_23176.edf': ['Patient Event',
#   'EOG LOC-M2',
#   'EOG ROC-M1',
#   'EMG Chin1-Chin2',
#   'EEG F3-M2',
#   'EEG F4-M1',
#   'EEG C3-M2',
#   'EEG C4-M1',
#   'EEG O1-M2',
#   'EEG O2-M1',
#   'EEG CZ-O1',
#   'EMG LLeg-RLeg',
#   'ECG EKG2-EKG',
#   'Snore',
#   'Resp PTAF',
#   'Resp Airflow',
#   'Resp Thoracic',
#   'Resp Abdominal',
#   'SpO2',
#   'Rate',
#   'EtCO2',
#   'Capno',
#   'Resp Rate',
#   'C-flow',
#   'Tidal Vol',
#   'Pressure'],
#  '211_25741.edf': ['Patient Event',
#   'EOG LOC-M2',
#   'EOG ROC-M1',
#   'EMG Chin1-Chin2',
#   'EEG F3-M2',
#   'EEG F4-M1',
#   'EEG C3-M2',
#   'EEG C4-M1',
#   'EEG O1-M2',
#   'EEG O2-M1',
#   'EEG CZ-O1',
#   'EMG LLeg-RLeg',
#   'ECG EKG2-EKG',
#   'Snore',
#   'Resp PTAF',
#   'Resp Airflow',
#   'Resp Thoracic',
#   'Resp Abdominal',
#   'SpO2',
#   'Rate',
#   'EtCO2',
#   'Capno',
#   'Resp Rate',
#   'C-flow',
#   'Tidal Vol',
#   'Pressure'],
#  '211_8290.edf': ['Patient Event',
#   'EOG LOC-M2',
#   'EOG ROC-M1',
#   'EMG CHIN1-CHIN2',
#   'EEG F3-M2',
#   'EEG F4-M1',
#   'EEG C3-M2',
#   'EEG C4-M1',
#   'EEG O1-M2',
#   'EEG O2-M1',
#   'EEG Cz-O1',
#   'EMG LLEG+-LLEG-',
#   'EMG RLEG+-RLEG-',
#   'ECG LA-RA',
#   'Snore',
#   'Snore_DR',
#   'Flow_DR',
#   'Resp Flow',
#   'XFlow',
#   'Resp Chest',
#   'Resp Abdomen',
#   'OSAT',
#   'Rate',
#   'EtCO2',
#   'Capno',
#   'Resp Rate',
#   'TcCO2',
#   'C-Flow',
#   'C-Pressure'],
#  '220_7708.edf': ['Patient Event',
#   'EOG LOC-M2',
#   'EOG ROC-M1',
#   'EMG Chin1-Chin2',
#   'EEG F3-M2',
#   'EEG F4-M1',
#   'EEG C3-M2',
#   'EEG C4-M1',
#   'EEG O1-M2',
#   'EEG O2-M1',
#   'EEG CZ-O1',
#   'EMG LLeg-RLeg',
#   'ECG EKG2-EKG',
#   'Snore',
#   'Resp PTAF',
#   'Resp Airflow',
#   'Resp Thoracic',
#   'Resp Abdominal',
#   'SpO2',
#   'Rate',
#   'EtCO2',
#   'Capno',
#   'Resp Rate',
#   'C-flow',
#   'Tidal Vol',
#   'Pressure']}

# %% [markdown]
# #### Extract just the EEG channels

# %%
eeg_per_rec = {}
for key in ch_per_rec:
    eeg_per_rec[key] = []
    channels = ch_per_rec[key]
    eeg_ch = [x for x in channels if 'EEG' in x]
    eeg_per_rec[key] = eeg_ch

# %%
eeg_per_rec
# Out:
# {'1_4789.edf': ['EEG F3-M2',
#   'EEG F4-M1',
#   'EEG C3-M2',
#   'EEG C4-M1',
#   'EEG O1-M2',
#   'EEG O2-M1',
#   'EEG CZ-O1'],
#  '10_22339.edf': ['EEG F3-M2',
#   'EEG F4-M1',
#   'EEG C3-M2',
#   'EEG C4-M1',
#   'EEG O1-M2',
#   'EEG O2-M1',
#   'EEG CZ-O1'],
#  '16_24241.edf': ['EEG F3-M2',
#   'EEG F4-M1',
#   'EEG C3-M2',
#   'EEG C4-M1',
#   'EEG O1-M2',
#   'EEG O2-M1',
#   'EEG CZ-O1'],
#  '22_23233.edf': ['EEG F3-M2',
#   'EEG F4-M1',
#   'EEG C3-M2',
#   'EEG C4-M1',
#   'EEG O1-M2',
#   'EEG O2-M1',
#   'EEG Cz-O1'],
#  '25_10579.edf': ['EEG F3-M2',
#   'EEG F4-M1',
#   'EEG C3-M2',
#   'EEG C4-M1',
#   'EEG O1-M2',
#   'EEG O2-M1',
#   'EEG Cz-O1'],
#  '25_18085.edf': ['EEG F3-M2',
#   'EEG F4-M1',
#   'EEG C3-M2',
#   'EEG C4-M1',
#   'EEG O1-M2',
#   'EEG O2-M1',
#   'EEG CZ-O1'],
#  '28_15280.edf': ['EEG F3-M2',
#   'EEG F4-M1',
#   'EEG C3-M2',
#   'EEG C4-M1',
#   'EEG O1-M2',
#   'EEG O2-M1',
#   'EEG Cz-O1'],
#  '31_4429.edf': ['EEG F3-M2',
#   'EEG F4-M1',
#   'EEG C3-M2',
#   'EEG C4-M1',
#   'EEG O1-M2',
#   'EEG O2-M1',
#   'EEG Cz-O1'],
#  '37_14779.edf': ['EEG F3-M2',
#   'EEG F4-M1',
#   'EEG C3-M2',
#   'EEG C4-M1',
#   'EEG O1-M2',
#   'EEG O2-M1',
#   'EEG CZ-O1'],
#  '7_12595.edf': ['EEG F3-M2',
#   'EEG F4-M1',
#   'EEG C3-M2',
#   'EEG C4-M1',
#   'EEG O1-M2',
#   'EEG O2-M1',
#   'EEG CZ-O1'],
#  '40_14503.edf': ['EEG F3-M2',
#   'EEG F4-M1',
#   'EEG C3-M2',
#   'EEG C4-M1',
#   'EEG O1-M2',
#   'EEG O2-M1',
#   'EEG CZ-O1'],
#  '43_175.edf': ['EEG F3-M2',
#   'EEG F4-M1',
#   'EEG C3-M2',
#   'EEG C4-M1',
#   'EEG O1-M2',
#   'EEG O2-M1',
#   'EEG CZ-O1'],
#  '46_11305.edf': ['EEG F3-M2',
#   'EEG F4-M1',
#   'EEG C3-M2',
#   'EEG C4-M1',
#   'EEG O1-M2',
#   'EEG O2-M1',
#   'EEG CZ-O1'],
#  '55_6112.edf': ['EEG F3-M2',
#   'EEG F4-M1',
#   'EEG C3-M2',
#   'EEG C4-M1',
#   'EEG O1-M2',
#   'EEG O2-M1',
#   'EEG CZ-O1'],
#  '61_19477.edf': ['EEG F3-M2',
#   'EEG F4-M1',
#   'EEG C3-M2',
#   'EEG C4-M1',
#   'EEG O1-M2',
#   'EEG O2-M1',
#   'EEG CZ-O1'],
#  '64_14908.edf': ['EEG F3-M2',
#   'EEG F4-M1',
#   'EEG C3-M2',
#   'EEG C4-M1',
#   'EEG O1-M2',
#   'EEG O2-M1',
#   'EEG CZ-O1'],
#  '64_25396.edf': ['EEG F3-M2',
#   'EEG F4-M1',
#   'EEG C3-M2',
#   'EEG C4-M1',
#   'EEG O1-M2',
#   'EEG O2-M1',
#   'EEG CZ-O1'],
#  '67_5998.edf': ['EEG F3-M2',
#   'EEG F4-M1',
#   'EEG C3-M2',
#   'EEG C4-M1',
#   'EEG O1-M2',
#   'EEG O2-M1',
#   'EEG CZ-O1'],
#  '70_20743.edf': ['EEG F3-M2',
#   'EEG F4-M1',
#   'EEG C3-M2',
#   'EEG C4-M1',
#   'EEG O1-M2',
#   'EEG O2-M1',
#   'EEG CZ-O1'],
#  '82_20809.edf': ['EEG F3-M2',
#   'EEG F4-M1',
#   'EEG C3-M2',
#   'EEG C4-M1',
#   'EEG O1-M2',
#   'EEG O2-M1',
#   'EEG Cz-O1'],
#  '100_23083.edf': ['EEG F3-M2',
#   'EEG F4-M1',
#   'EEG C3-M2',
#   'EEG C4-M1',
#   'EEG O1-M2',
#   'EEG O2-M1',
#   'EEG CZ-O1'],
#  '103_12325.edf': ['EEG F3-M2',
#   'EEG F4-M1',
#   'EEG C3-M2',
#   'EEG C4-M1',
#   'EEG O1-M2',
#   'EEG O2-M1',
#   'EEG CZ-O1'],
#  '115_22774.edf': ['EEG F3-M2',
#   'EEG F4-M1',
#   'EEG C3-M2',
#   'EEG C4-M1',
#   'EEG O1-M2',
#   'EEG O2-M1',
#   'EEG CZ-O1'],
#  '121_23845.edf': ['EEG F3-M2',
#   'EEG F4-M1',
#   'EEG C3-M2',
#   'EEG C4-M1',
#   'EEG O1-M2',
#   'EEG O2-M1',
#   'EEG Cz-O1'],
#  '127_19126.edf': ['EEG F3-M2',
#   'EEG F4-M1',
#   'EEG C3-M2',
#   'EEG C4-M1',
#   'EEG O1-M2',
#   'EEG O2-M1',
#   'EEG CZ-O1'],
#  '130_5164.edf': ['EEG F3-M2',
#   'EEG F4-M1',
#   'EEG C3-M2',
#   'EEG C4-M1',
#   'EEG O1-M2',
#   'EEG O2-M1',
#   'EEG CZ-O1'],
#  '136_4501.edf': ['EEG F3-M2',
#   'EEG F4-M1',
#   'EEG C3-M2',
#   'EEG C4-M1',
#   'EEG O1-M2',
#   'EEG O2-M1',
#   'EEG CZ-O1'],
#  '91_15028.edf': ['EEG F3-M2',
#   'EEG F4-M1',
#   'EEG C3-M2',
#   'EEG C4-M1',
#   'EEG O1-M2',
#   'EEG O2-M1',
#   'EEG CZ-O1'],
#  '91_18331.edf': ['EEG F3-M2',
#   'EEG F4-M1',
#   'EEG C3-M2',
#   'EEG C4-M1',
#   'EEG O1-M2',
#   'EEG O2-M1',
#   'EEG CZ-O1'],
#  '91_3787.edf': ['EEG F3-M2',
#   'EEG F4-M1',
#   'EEG C3-M2',
#   'EEG C4-M1',
#   'EEG O1-M2',
#   'EEG O2-M1',
#   'EEG CZ-O1'],
#  '139_20275.edf': ['EEG F3-M2',
#   'EEG F4-M1',
#   'EEG C3-M2',
#   'EEG C4-M1',
#   'EEG O1-M2',
#   'EEG O2-M1',
#   'EEG CZ-O1'],
#  '145_1537.edf': ['EEG F3-M2',
#   'EEG F4-M1',
#   'EEG C3-M2',
#   'EEG C4-M1',
#   'EEG O1-M2',
#   'EEG O2-M1',
#   'EEG CZ-O1'],
#  '148_568.edf': ['EEG F3-M2',
#   'EEG F4-M1',
#   'EEG C3-M2',
#   'EEG C4-M1',
#   'EEG O1-M2',
#   'EEG O2-M1',
#   'EEG CZ-O1'],
#  '151_23734.edf': ['EEG F3-M2',
#   'EEG F4-M1',
#   'EEG C3-M2',
#   'EEG C4-M1',
#   'EEG O1-M2',
#   'EEG O2-M1',
#   'EEG CZ-O1'],
#  '154_18469.edf': ['EEG F3-M2',
#   'EEG F4-M1',
#   'EEG C3-M2',
#   'EEG C4-M1',
#   'EEG O1-M2',
#   'EEG O2-M1',
#   'EEG Cz-O1'],
#  '157_6391.edf': ['EEG F3-M2',
#   'EEG F4-M1',
#   'EEG C3-M2',
#   'EEG C4-M1',
#   'EEG O1-M2',
#   'EEG O2-M1',
#   'EEG CZ-O1'],
#  '160_11500.edf': ['EEG F3-M2',
#   'EEG F4-M1',
#   'EEG C3-M2',
#   'EEG C4-M1',
#   'EEG O1-M2',
#   'EEG O2-M1',
#   'EEG CZ-O1'],
#  '160_12856.edf': ['EEG F3-M2',
#   'EEG F4-M1',
#   'EEG C3-M2',
#   'EEG C4-M1',
#   'EEG O1-M2',
#   'EEG O2-M1',
#   'EEG CZ-O1'],
#  '160_2740.edf': ['EEG F3-M2',
#   'EEG F4-M1',
#   'EEG C3-M2',
#   'EEG C4-M1',
#   'EEG O1-M2',
#   'EEG O2-M1',
#   'EEG CZ-O1'],
#  '163_20485.edf': ['EEG F3-M2',
#   'EEG F4-M1',
#   'EEG C3-M2',
#   'EEG C4-M1',
#   'EEG O1-M2',
#   'EEG O2-M1',
#   'EEG Cz-O1'],
#  '166_10357.edf': ['EEG F3-M2',
#   'EEG F4-M1',
#   'EEG C3-M2',
#   'EEG C4-M1',
#   'EEG O1-M2',
#   'EEG O2-M1',
#   'EEG Cz-O1'],
#  '181_12274.edf': ['EEG F3-M2',
#   'EEG F4-M1',
#   'EEG C3-M2',
#   'EEG C4-M1',
#   'EEG O1-M2',
#   'EEG O2-M1',
#   'EEG CZ-O1'],
#  '184_2509.edf': ['EEG F3-M2',
#   'EEG F4-M1',
#   'EEG C3-M2',
#   'EEG C4-M1',
#   'EEG O1-M2',
#   'EEG O2-M1',
#   'EEG CZ-O1'],
#  '187_6160.edf': ['EEG F3-M2',
#   'EEG F4-M1',
#   'EEG C3-M2',
#   'EEG C4-M1',
#   'EEG O1-M2',
#   'EEG O2-M1',
#   'EEG CZ-O1'],
#  '190_9877.edf': ['EEG Chin3-Chin2',
#   'EEG F3-M2',
#   'EEG F4-M1',
#   'EEG C3-M2',
#   'EEG C4-M1',
#   'EEG O1-M2',
#   'EEG O2-M1',
#   'EEG CZ-O1'],
#  '202_13666.edf': ['EEG F3-M2',
#   'EEG F4-M1',
#   'EEG C3-M2',
#   'EEG C4-M1',
#   'EEG O1-M2',
#   'EEG O2-M1',
#   'EEG Cz-O1'],
#  '205_23176.edf': ['EEG F3-M2',
#   'EEG F4-M1',
#   'EEG C3-M2',
#   'EEG C4-M1',
#   'EEG O1-M2',
#   'EEG O2-M1',
#   'EEG CZ-O1'],
#  '211_25741.edf': ['EEG F3-M2',
#   'EEG F4-M1',
#   'EEG C3-M2',
#   'EEG C4-M1',
#   'EEG O1-M2',
#   'EEG O2-M1',
#   'EEG CZ-O1'],
#  '211_8290.edf': ['EEG F3-M2',
#   'EEG F4-M1',
#   'EEG C3-M2',
#   'EEG C4-M1',
#   'EEG O1-M2',
#   'EEG O2-M1',
#   'EEG Cz-O1'],
#  '220_7708.edf': ['EEG F3-M2',
#   'EEG F4-M1',
#   'EEG C3-M2',
#   'EEG C4-M1',
#   'EEG O1-M2',
#   'EEG O2-M1',
#   'EEG CZ-O1']}

# %% [markdown]
# **Need to extract common channels**

# %%
master_channels = eeg_per_rec[edf_files[0]]
master_channels.sort()

# %%
master_channels
# Out:
# ['EEG C3-M2',
#  'EEG C4-M1',
#  'EEG CZ-O1',
#  'EEG F3-M2',
#  'EEG F4-M1',
#  'EEG O1-M2',
#  'EEG O2-M1']

# %%
eeg_per_rec_upper = {}

for key in eeg_per_rec:
    channel_upper = []
    cur_channels = eeg_per_rec[key]
    for x in cur_channels:
        channel_upper.append(x.upper())
    eeg_per_rec_upper[key] = channel_upper

# %%
contains_master = {}

for key in eeg_per_rec_upper:
    contains_master[key] = []
    cur_channels = eeg_per_rec_upper[key]
    if all(elem in cur_channels for elem in master_channels):
        contains_master[key].append(True)

# %%
contains_master
# Out:
# {'1_4789.edf': [True],
#  '10_22339.edf': [True],
#  '16_24241.edf': [True],
#  '22_23233.edf': [True],
#  '25_10579.edf': [True],
#  '25_18085.edf': [True],
#  '28_15280.edf': [True],
#  '31_4429.edf': [True],
#  '37_14779.edf': [True],
#  '7_12595.edf': [True],
#  '40_14503.edf': [True],
#  '43_175.edf': [True],
#  '46_11305.edf': [True],
#  '55_6112.edf': [True],
#  '61_19477.edf': [True],
#  '64_14908.edf': [True],
#  '64_25396.edf': [True],
#  '67_5998.edf': [True],
#  '70_20743.edf': [True],
#  '82_20809.edf': [True],
#  '100_23083.edf': [True],
#  '103_12325.edf': [True],
#  '115_22774.edf': [True],
#  '121_23845.edf': [True],
#  '127_19126.edf': [True],
#  '130_5164.edf': [True],
#  '136_4501.edf': [True],
#  '91_15028.edf': [True],
#  '91_18331.edf': [True],
#  '91_3787.edf': [True],
#  '139_20275.edf': [True],
#  '145_1537.edf': [True],
#  '148_568.edf': [True],
#  '151_23734.edf': [True],
#  '154_18469.edf': [True],
#  '157_6391.edf': [True],
#  '160_11500.edf': [True],
#  '160_12856.edf': [True],
#  '160_2740.edf': [True],
#  '163_20485.edf': [True],
#  '166_10357.edf': [True],
#  '181_12274.edf': [True],
#  '184_2509.edf': [True],
#  '187_6160.edf': [True],
#  '190_9877.edf': [True],
#  '202_13666.edf': [True],
#  '205_23176.edf': [True],
#  '211_25741.edf': [True],
#  '211_8290.edf': [True],
#  '220_7708.edf': [True]}

# %% [markdown]
# ### Actually extracting the EEG data

# %% [markdown]
# **Trial with 1 recording**

# %%
test_rec
edfpath = os.path.join(raw_path, test_rec)

# %%
rawedf = mne.io.read_raw_edf(edfpath)
# Out:
# Extracting EDF parameters from /workspace/Competition/PSG/01_DATA/raw/1_4789.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...

# %%
rawedf['EEG C3-M2'][0].shape, rawedf['EEG C3-M2'][1].shape
# Out:
# ((1, 8877056), (8877056,))

# %%
times = rawedf['EEG C3-M2'][1]

# %%
times
# Out:
# array([0.00000000e+00, 3.90625000e-03, 7.81250000e-03, ...,
#        3.46759883e+04, 3.46759922e+04, 3.46759961e+04])

# %%
times[1]-times[0], times[2]-times[1], times[3]-times[2], times[-1]-times[-2]
# Out:
# (0.00390625, 0.00390625, 0.00390625, 0.00390625)

# %%
raw_eegs = []

for eeg in eeg_per_rec[test_rec]:
    if eeg.upper() in master_channels:
        raw_eegs.append(rawedf[eeg][0])

# %%
a = np.concatenate(raw_eegs, axis=0)

# %%
a.shape
# Out:
# (7, 8877056)

# %%
master_channels.sort()
master_channels
# Out:
# ['EEG C3-M2',
#  'EEG C4-M1',
#  'EEG CZ-O1',
#  'EEG F3-M2',
#  'EEG F4-M1',
#  'EEG O1-M2',
#  'EEG O2-M1']

# %%
rec
# Out:
# '1_4789.edf'

# %%
edfpath
# Out:
# '/workspace/Competition/PSG/01_DATA/raw/1_4789.edf'

# %%
eeg_channels
# Out:
# []

# %%
rec = edf_files[0]
rec
# Out:
# '1_4789.edf'
